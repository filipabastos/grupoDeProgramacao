# %% [markdown]
# **Importar bibliotecas e ler ficheiro.**

# %%
from pandas import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = read_csv('company_sales_UPDATE.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# **EXERCICIO 1**

# %% [markdown]
# Ler o lucro total (Total Profit) de todos os meses e mostre-os através de um gráfico de linhas.
# Usar o dado fornecido do lucro total para cada mês. A gráfico de linha gerado deve incluir as seguintes propriedades:
# X label name = Month Number
# Y label name = Total profit
#
# Criar as seguintes listas:
#     profutdList = df["total_proft"].tolist()
#     monthList = df["month_numer"].tolist()

# %%
profitList = df ['total_profit'].tolist()
monthList = df ['month_number'].tolist()

y=profitList
x=monthList

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title("Lucro da empresa por mês", fontsize=20)
ax.set_xlabel("Número do mês", fontsize= 14)
ax.set_ylabel("Lucro em Dolares", fontsize= 14)

plt.plot(x,y)
print("Exercício 1")
# Out:
# Exercício 1

# %% [markdown]
# **EXERCICIO 2**

# %% [markdown]
# Ler o lucro total (Total Profit) de todos os meses e apresente-os num gráfico de linhas, com as características indicadas.
# A linha gerada deve incluir as seguintes propriedades de estilo:
# Estilo de linha pontilhado e cor da linha devem ser vermelhos
# Mostrar legenda no local inferior direito
# Label do rótulo X = Número do mês
# Label do rótulo Y = Número de unidades vendidas
# Adicione um marcador de círculo
# Cor do marcador de linha conforme lida
# A largura da linha deve ser 3
# profitList = df["total_profit"].tolist()
# monthList = ["month_number"].tolist()

# %%
profitList = df['total_profit'].tolist()
monthList = df['month_number'].tolist()
y=profitList
x=monthList

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title("Lucro mensal da empresa do ano passado", fontsize=20)
ax.set_xlabel("Mês", fontsize= 14)
ax.set_ylabel("Lucro em Dolares", fontsize= 14)

plt.plot(x,y, "r--.", linewidth=3 , marker= 'o',  markerfacecolor='black', markersize=8)

print("Exercício 2")
# Out:
# Exercício 2

# %% [markdown]
# **EXERCICIO 3**

# %% [markdown]
# Mostrar as vendas mensais de todos os produtos num gráfico de múltiplas linhas, ou seja, uma linha diferente para cada produto.

# %%
plt.figure(figsize=(15,5))

x=df.month_number
y=df.total_profit

plt.title("Informação de Vendas")
plt.xlabel('Número do mês')
plt.ylabel('Vendas Unitárias')


cremeFacial = plt.plot(df.facecream, '.-', markersize=15, linewidth=1, label="Creme Facial")
sabaoFacial = plt.plot(df.facewash, '.-', markersize=15, linewidth=1, label="Sabão Facial")
pastaDentes = plt.plot(df.toothpaste, '.-', markersize=15, linewidth=1, label="Pasta de Dentes")
sabonete = plt.plot(df.bathingsoap, '.-', markersize=15, linewidth=1, label="Sabonete")
shampoo = plt.plot(df.shampoo, '.-', markersize=15, linewidth=1, label="Shampoo")
cremeHidratante = plt.plot(df.moisturizer, '.-', markersize=15, linewidth=1, label="Creme Hidratante")

print("Exercício 3")
plt.legend()
plt.show()
# Out:
# Exercício 3

# %% [markdown]
# **EXERCICIO 4**

# %% [markdown]
# Calcular para cada produto o total das vendas do ano e mostre-os usando Pie Chart (gráfico de queijo).
# No Pie chart inscrever a % de vendas de cada produto.

# %%
sumVendCreme = df["facecream"].sum()
sumVendSabaoFacial = df["facewash"].sum()
sumVendPasta = df["toothpaste"].sum()
sumVendSabonete = df["bathingsoap"].sum()
sumVendShampoo = df["shampoo"].sum()
sumVendHidratante = df["moisturizer"].sum()

totalunits = df["total_units"].sum()
totVendCreme = (sumVendCreme / totalunits) 
totVendSabaoFacial = (sumVendSabaoFacial / totalunits) 
totVendPasta = (sumVendPasta / totalunits) 
totVendSabonete = (sumVendSabonete / totalunits) 
totVendShampoo = (sumVendShampoo / totalunits) 
totVendHidratante = (sumVendHidratante / totalunits)


dados = [totVendCreme,totVendSabaoFacial,totVendPasta,totVendSabonete,totVendShampoo,totVendHidratante]
rotulos = ["Creme Facial","Sabão Facial","Pasta de Dentes","Sabonete","Shampoo","Creme Hidratante"]

plt.axis("equal")
plt.pie(dados,labels = rotulos,radius=3,autopct = "%0.2f%%",shadow=True, startangle=45)

print("Exercício 4")
plt.show()
# Out:
# Exercício 4
