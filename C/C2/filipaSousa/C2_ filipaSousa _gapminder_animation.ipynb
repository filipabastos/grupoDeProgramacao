# %% [markdown]
# **Gapminder_animation**

# %%
# libraries
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import seaborn as sns
sns.set_style("white")
import pandas as pd
my_dpi=96

# %% [markdown]
# **Importar ficheiro em csv da internet, para posterioremente ler com a biblioteca pandas, e confirmar a sua correta importação através da função head que por default mostra as primeiras 5 linhas.**

# %%
# Get the data (csv file is hosted on the web)
url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'
data = pd.read_csv(url)
#data=pd.read_csv('gapminderData.csv')
data.head()

# %% [markdown]
# **Separar a info dentro da "continente" no caso em cinco valores diferentes**

# %%
# And I need to transform my categorical column (continent) in a numerical value group1->1, group2->2...
data['continent']=pd.Categorical(data['continent'])

# %% [markdown]
# **QUESTAO A - Descrição do Código**
#
# Inicialmente importar matplotlib, definir um ciclo "for" para que se possa percorrer os vários anos da coluna "year",
# posteriormente determinamos a largura dos eixos (na linha de código:fig=plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)).
#
# De seguida definimos um tempo para apresentar os anos e o decorrer dos mesmos tendo em baseesta linha:tmp=data[ data.year == i ]
# Para apresentar escolhemos o plt.scatter
#
# definimos o eixo x  com 'lifeExp', e o eixo y com 'gdpPercap' , o parametro s define o tamanho de marcador que no caso será definido pala coluna ['pop']/20000, c = é reponsavel pela atribuição de cor que neste caso estará associado aos 5 continentes, os restantes parametros realacionam-se com as caracteristicas fisicas da bolhas.
#
# No # Add titles definimos, labels e escala de apresentação (no caso a logaritmica) para o eixo dos y, e por fim limitaos os intervalos de valores a apresentar em cada um dos eixos, e no titulo do gráfico definimos que seria o nome "Year" que será apresentado em conjunto com o valor do ano.
#
# O "Save it"  guarda e salva em jpg.

# %% [markdown]
# **QUESTAO A METODO - Interpretação**

# %% [markdown]
# A contrução deste gráfico foi através do método plot scatter. Podemos ver como, ao longo dos anos, nos cinco continentes, a evolução da relação do GDP per Capita e o Life Expectancy que se vai fazendo mostrar no gráfico graças ao ciclo "for"
#
# O ciclo for vai se servir da variavel anos para encontrar todas as informações da relação entre "Life Expentacy" e "GDP per Capita" referentes a cada continente, mostrando estas informações no decorrer dos anos, e exibindo estas informações nos vários gráficos que vemos abaixo.
#
# Desta forma conseguimos entender a relação existente entre as variáveis lifeExp (esperança média de vida) e gdpPercap (PIB per capita), os autores consideraram a esperança média de vida como a variável independente e o PIB per capita como variável dependente.

# %% [markdown]
# **Questão B Temos “bolhas” de cinco (5) cores diferentes. O que representa cada cor? Justifique, com descrição detalhada do processo.**

# %% [markdown]
# As cinco cores representadas são os 5 continentes que foram agrupadas por categorias (na linha de código data["continent"]=pd.Categorical(data["continent"]) e  poderiamos confirmar que o número de continentes é cinco através deste código: numeroContinentes = data.continent.unique()). Foi através do parametro c (c=tmp['continent'].cat.codes)
# que se definiu a representação destas cores dos diferentes continentes para serem apresentadas no gráfico.

# %%
# %matplotlib notebook
# %matplotlib notebook
 
# For each year:
for i in data.year.unique():
 
# initialize a figure
    fig=plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)
 
# Change color with c and alpha. I map the color to the X axis value.
    tmp=data[ data.year == i ]
    plt.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
 
# Add titles (main and on axis)
    plt.yscale('log')
    plt.xlabel("Life Expectancy")
    plt.ylabel("GDP per Capita")
    plt.title("Year: "+str(i) )
    plt.ylim(0,100000)
    plt.xlim(30, 90)
 
# Save it
    filename='Gapminder_step'+str(i)+'.png'
    plt.savefig(filename, dpi=96)
    plt.gca()

#Transformation in a GIF using Image Magick

# Then use image magick (this is bash, not python)
#magick convert -delay 80 Gapminder*.png animated_gapminder.gif
# Out:
# <img src="data:image/png;base64,..." width="680">
# C:\Users\spicy\anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
# <img src="data:image/png;base64,..." width="680">
